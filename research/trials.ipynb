# %%
d = {'key': 'value', 'key1': 'value1'}

# %%
d['key']
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({'key': 'value', 'key1':'value1'})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key
# Out:
# 'value'

# %% [markdown]
# this is why we use config box in the rest of the code

# %%
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x =2, y = 4)
# Out:
# 8

# %%
get_product(x =2, y = '4')
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_predict(x:int, y:int) -> int:
    return x*y

get_predict(x =2, y = '4')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[17], line 5
#       1 @ensure_annotations
#       2 def get_predict(x:int, y:int) -> int:
#       3     return x*y
# ----> 5 get_predict(x =2, y = '4')
#
# File c:\Users\ahmed\OneDrive\Documents\Documents\coding\data science\DataScience\MLOPS-Project\venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# ...

# %% [markdown]
# so we are using ensure_annotations to make sure our function only takes the specific data type

# %% [markdown]
# In config.yaml we will pull the file from source which is github and then store the file as data.zip and then store the data again after unzipping.

# %% [markdown]
# in utils i create the functions for specific packages, example: constant folder is constant package and utils in constant folder contains the functions that can be accesible when we call the constant package.

# %% [markdown]
# ## Here is how everything works
#
# once you set up the template.py
#
# * then setup the setup.py
#
# * in a folder (research folder) create notebook for each stage(examples data ingestion),
# * now in the notebook create steps required for that stage.
# * execute the notebook to see if that works, now put them in the src folder, put entity step at the config_entity.py
# * put cofiguration mangager at config -> configurations.py
# * create a file at components folder for this stage and then add the component from your notebook
# * go to pipeline folder and create file for this stage and add the pipeline for this stage from the notebook
#
# * then go to main.py give stage name and the pipeline code in main.py from your pipeline file for this stage.
# * now run the main.py in terminal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# while deplying
#
# the cicd pipeline, the cd failed
